# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def function(x):
    return (x-4)*(x-4)

# %%
def dichotomy(a, b, e, ee):
    while True:
        x = (a + b)/2
        y1 = function(x-ee)
        y2 = function(x+ee)
        if y1 <= y2:
            b = x + ee
        else:
            a = x - ee
        
        if b - a <= 2 * e:
            return (a + b)/2

# %%
a = -3
b = 14
e = 0.0001
ee = 0.000001

# %%
min_x = dichotomy(a, b, e, ee)
x = np.arange(a, b+1)
y = []
[y.append(function(i)) for i in range(a, b+1)]
print(y)
# Out:
# [49, 36, 25, 16, 9, 4, 1, 0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
plt.plot(x, y, color = 'purple')
plt.scatter(min_x, function(min_x), color = 'red')
print(min_x)
# Out:
# 3.999958214805602
